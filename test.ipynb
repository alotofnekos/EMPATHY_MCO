# %%
# Test cell

from transformers import pipeline

classifier = pipeline(task="text-classification", model="SamLowe/roberta-base-go_emotions", top_k=None)

sentences = ["I am not having a great day"]

model_outputs = classifier(sentences)
print(model_outputs[0])
# produces a list of dicts for each of the labels
# Out:
# WARNING:tensorflow:From c:\Users\jmcvi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# c:\Users\jmcvi\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:149: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\jmcvi\.cache\huggingface\hub\models--SamLowe--roberta-base-go_emotions. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...

# %%
model_outputs[0][0]['label']
# Out:
# 'disappointment'

# %%
import pandas as pd
import numpy as np

# %%
# Load CSVs into pandas dataframes

indianfood_df = pd.read_csv('indian_food.csv')

indianfood_df.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region
# 0   East
# 1   West
# 2  North
# 3   West
# 4   East

# %%
allergen_df = pd.read_csv('rows.csv')

# %%
allergen_df.head()
# Out:
#      ingredients Milk lactose intolerace Tree Nut Peanut  Egg Wheat Fish   Soy
# 0         elachi  NaN                NaN      NaN    NaN  NaN   NaN   NaN  NaN
# 1  vegetable oil  NaN                NaN      NaN    NaN  NaN   NaN   NaN  NaN
# 2           ghee  NaN                NaN      NaN    NaN  NaN   NaN   NaN  NaN
# 3        jaggery  NaN                NaN      NaN    NaN  NaN   NaN   NaN  NaN
# 4     Rice flour  NaN                NaN      NaN    NaN  NaN   NaN   NaN  NaN

# %%
# Display unique values of each column in the allergen df

for column in allergen_df.columns:
    print(column, allergen_df[column].unique())
# Out:
# ingredients ['elachi' 'vegetable oil' 'ghee' 'jaggery' 'Rice flour' 'curry leaves'
#  'turmeric' 'garam masala' 'potato' 'Cauliflower' 'garlic' 'ginger'
#  'chillies' 'peas' 'oil' 'salt' 'fenugreek leaves' 'amchur powder'
#  'shimla mirch' 'bread crumbs' 'green chillies' 'fish' 'mustard oil'
#  'Potatoes' 'hot water' 'mustard seeds' 'arhar dal' 'Kala masala'
#  'khus-khus seeds' 'green chilli' 'kala jeera' 'Whole wheat flour'
#  'urad dal' 'tindora' 'long beans' 'elephant foot yam' 'Raw banana'
#  'pearl millet flour' 'Wheat flour' 'sugar' 'yogurt' 'Maida flour'
#  'jaggery syrup' 'cashews and raisins' 'cardamom powder' 'Besan' 'nuts'
#  'milk' 'all purpose flour' 'clarified butter' 'egg yolks' 'Coconut milk'
#  'chili powder' 'green chilies' 'coconut' 'Beef' 'coriander'
#  'sesame seeds' 'onions' 'Brinjal' 'Jowar flour' 'baking soda'
#  'plain flour' 'rava' 'Chole' 'tomatoes' 'kasuri methi' 'Ladies finger'
#  'bay leaf' 'sweet' 'star anise' 'basmati rice' 'Chicken thighs'
# ...

# %%
allergen_df
# Out:
#        ingredients Milk lactose intolerace Tree Nut Peanut  Egg Wheat Fish   \
# 0           elachi  NaN                NaN      NaN    NaN  NaN   NaN   NaN
# 1    vegetable oil  NaN                NaN      NaN    NaN  NaN   NaN   NaN
# 2             ghee  NaN                NaN      NaN    NaN  NaN   NaN   NaN
# 3          jaggery  NaN                NaN      NaN    NaN  NaN   NaN   NaN
# 4       Rice flour  NaN                NaN      NaN    NaN  NaN   NaN   NaN
# ..             ...  ...                ...      ...    ...  ...   ...   ...
# 360    valor papdi  NaN                NaN      NaN    NaN  NaN   NaN   NaN
# 361    surti papdi  NaN                NaN      NaN    NaN  NaN   NaN   NaN
# 362   Sweet potato  NaN                NaN      NaN    NaN  NaN   NaN   NaN
# 363      Baby corn  NaN                NaN      NaN    NaN  NaN   NaN   NaN
# 364   wine vinegar  NaN                NaN      NaN    NaN  NaN   NaN   NaN
#
#      Soy allergens
# 0    NaN
# 1    NaN
# 2    NaN
# ...

# %%
# Fixing allergen list

# Add 'allergens' column to the df
allergen_df['allergens'] = np.empty((len(allergen_df), 0)).tolist()

allergen_df
# Out:
#        ingredients Milk lactose intolerace Tree Nut Peanut  Egg Wheat Fish   \
# 0           elachi  NaN                NaN      NaN    NaN  NaN   NaN   NaN
# 1    vegetable oil  NaN                NaN      NaN    NaN  NaN   NaN   NaN
# 2             ghee  NaN                NaN      NaN    NaN  NaN   NaN   NaN
# 3          jaggery  NaN                NaN      NaN    NaN  NaN   NaN   NaN
# 4       Rice flour  NaN                NaN      NaN    NaN  NaN   NaN   NaN
# ..             ...  ...                ...      ...    ...  ...   ...   ...
# 360    valor papdi  NaN                NaN      NaN    NaN  NaN   NaN   NaN
# 361    surti papdi  NaN                NaN      NaN    NaN  NaN   NaN   NaN
# 362   Sweet potato  NaN                NaN      NaN    NaN  NaN   NaN   NaN
# 363      Baby corn  NaN                NaN      NaN    NaN  NaN   NaN   NaN
# 364   wine vinegar  NaN                NaN      NaN    NaN  NaN   NaN   NaN
#
#      Soy allergens
# 0    NaN        []
# ...

# %%
# Create a column for the allergens of each ingredient
for index, row in allergen_df.iterrows():
    if row['Milk'] == 'y':
        row['allergens'].append('milk')
    if row['lactose intolerace'] == 'y':
        row['allergens'].append('lactose')
    if row['Tree Nut'] == 'y':
        row['allergens'].append('tree nut')
    if row['Peanut'] == 'y':
        row['allergens'].append('peanut')
    if row['Egg'] == 'y':
        row['allergens'].append('egg')
    if row['Wheat'] == 'y':
        row['allergens'].append('wheat')
    if row ['Fish '] == 'y':
        row['allergens'].append('shellfish')
    if row['Soy'] == 'y':
        row['allergens'].append('soy')
